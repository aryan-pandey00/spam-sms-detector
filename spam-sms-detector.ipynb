# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('sms_spam.csv', encoding='latin1')
df
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
# ...    ...                                                ...        ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 0           NaN        NaN
# 1           NaN        NaN
# 2           NaN        NaN
# 3           NaN        NaN
# 4           NaN        NaN
# ...         ...        ...
# 5567        NaN        NaN
# 5568        NaN        NaN
# 5569        NaN        NaN
# 5570        NaN        NaN
# 5571        NaN        NaN
#
# [5572 rows x 5 columns]

# %% [markdown]
# # 1. <u>Data  Cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
# drop last 3 columns
df.drop(columns = ['Unnamed: 2','Unnamed: 3','Unnamed: 4'],inplace =True)

# %%
df.sample(5)
# Out:
#        v1                                                 v2
# 2696  ham  Nope but i'm going home now then go pump petro...
# 3844  ham                   Mmmm.... I cant wait to lick it!
# 4129  ham                 And by when you're done I mean now
# 3029  ham  Also sir, i sent you an email about how to log...
# 2854  ham  Your gonna be the death if me. I'm gonna leave...

# %%
# renaming the columns as they are not descriptive
df.rename(columns = {'v1':'target','v2':'text'},inplace = True)
df.sample(5)
# Out:
#      target                                               text
# 4192    ham                            Ok i'm coming home now.
# 2645    ham                             Sorry, I'll call later
# 40      ham  Pls go ahead with watts. I just wanted to be s...
# 1583    ham  It's cool, let me know before it kicks off aro...
# 1041    ham                     I'm in class. Will holla later

# %%
# in taget we want number instead of text so assigning number to them
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
df['target'] = encoder.fit_transform(df['target'])

# %%
df.head()
# Out:
#    target                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
# check for missing values
df.isnull().sum()
# Out:
# target    0
# text      0
# dtype: int64

# %%
# check for duplicate values
df.duplicated().sum()
# Out:
# np.int64(403)

# %%
# remove duplicates
df = df.drop_duplicates(keep = 'first')

# %%
# checking duplicacy is removed or not 
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (5169, 2)

# %% [markdown]
# # 2. <u> EDA

# %%
df.head()
# Out:
#    target                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
df['target'].value_counts().rename('target')
# Out:
# target
# 0    4516
# 1     653
# Name: target, dtype: int64

# %%
# to analyze data, create a pie chart
import matplotlib.pyplot as plt
plt.pie(df['target'].value_counts(),labels = ['ham','spam'], autopct = '%0.2f')
plt.show()

# %% [markdown]
# From above we can clearly say that our data is imbalanced because ham is very high as compared to spam

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\aryan\anaconda3\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\aryan\anaconda3\lib\site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in c:\users\aryan\anaconda3\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\aryan\anaconda3\lib\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\aryan\anaconda3\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\aryan\anaconda3\lib\site-packages (from click->nltk) (0.4.6)

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\aryan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\aryan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
# it gives length of all messages or character used
df = df.copy()
df['num_characters'] = df['text'].apply(len)

# %%
df.head()
# Out:
#    target                                               text  num_characters
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61

# %%
# it seperates all word and gives total number of words in a message
df = df.copy()
df['num_words'] = df['text'].apply(lambda x : len(nltk.word_tokenize(x)))

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words
# 0         24
# 1          8
# 2         37
# 3         13
# 4         15

# %%
# it seperate sentences
df = df.copy()
df ['num_sentences'] = df['text'].apply(lambda x : len(nltk.sent_tokenize(x)))

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences
# 0         24              2
# 1          8              2
# 2         37              2
# 3         13              1
# 4         15              1

# %%
# it tells about information of sms (include both ham and spam messages)
df[['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters    num_words  num_sentences
# count     5169.000000  5169.000000    5169.000000
# mean        78.977945    18.455794       1.965564
# std         58.236293    13.324758       1.448541
# min          2.000000     1.000000       1.000000
# 25%         36.000000     9.000000       1.000000
# 50%         60.000000    15.000000       1.000000
# 75%        117.000000    26.000000       2.000000
# max        910.000000   220.000000      38.000000

# %%
# ham messages
df[df['target'] == 0][['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters    num_words  num_sentences
# count     4516.000000  4516.000000    4516.000000
# mean        70.459256    17.123782       1.820195
# std         56.358207    13.493970       1.383657
# min          2.000000     1.000000       1.000000
# 25%         34.000000     8.000000       1.000000
# 50%         52.000000    13.000000       1.000000
# 75%         90.000000    22.000000       2.000000
# max        910.000000   220.000000      38.000000

# %%
# spam messages
df[df['target'] == 1][['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters   num_words  num_sentences
# count      653.000000  653.000000     653.000000
# mean       137.891271   27.667688       2.970904
# std         30.137753    7.008418       1.488425
# min         13.000000    2.000000       1.000000
# 25%        132.000000   25.000000       2.000000
# 50%        149.000000   29.000000       3.000000
# 75%        157.000000   32.000000       4.000000
# max        224.000000   46.000000       9.000000

# %%
# plot histogram for better visualization
import seaborn as sns

# %%
# for number of characters
plt.figure(figsize = (12,6))
sns.histplot(df[df['target'] == 0]['num_characters'])
sns.histplot(df[df['target'] == 1]['num_characters'], color = 'red')
plt.show()

# %%
# for number of words
plt.figure(figsize = (12,6))
sns.histplot(df[df['target'] == 0]['num_words'])
sns.histplot(df[df['target'] == 1]['num_words'], color = 'red')
plt.show()

# %%
sns.pairplot(df,hue = 'target')
plt.show()

# %%
# Select only numeric columns for correlation
numeric_df = df[['target', 'num_characters', 'num_words', 'num_sentences']]

# Calculate correlation and generate heatmap
sns.heatmap(numeric_df.corr(), annot=True)
plt.show()

# %% [markdown]
# # 3. <u> Data Preprocessing
#
# - Lower Case
# - Tokenization
# - Removing special characters
# - Removing stop words and punctuation
# - Stemming

# %%
# stopwords are words only used for sentance making not necessary for understanding
from nltk.corpus import stopwords
import string

# %%
import nltk
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

#ps.stem('loving') # --> it gives root word remove its different forms having same meaning

# %%
def transform_text(text):
    # converting into lower case
    text = text.lower()

    # converting into tokens
    text = nltk.word_tokenize(text)

    # removing special characters
    y = []
    for i in text:
        if i.isalnum():
            y.append(i)

    # Removing stop words and punctuation
    text = y[:]
    y.clear()

    for i in text:
        if i not in stopwords.words('english') and i not in string.punctuation:
            y.append(i)

    # Stemming 
    text = y[:]
    y.clear()

    for i in text :
        y.append(ps.stem(i))

    return " ".join(y)

# %%
# just checking above function
transform_text("Do I know you Aryan ?")
# Out:
# 'know aryan'

# %%
# just another example for checking above function
df['text'][20]
# Out:
# 'Is that seriously how you spell his name?'

# %%
df['transformed_text'] = df['text'].apply(transform_text)

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences                                   transformed_text
# 0         24              2  go jurong point crazi avail bugi n great world...
# 1          8              2                              ok lar joke wif u oni
# 2         37              2  free entri 2 wkli comp win fa cup final tkt 21...
# 3         13              1                u dun say earli hor u c alreadi say
# 4         15              1               nah think goe usf live around though

# %%
! pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\aryan\anaconda3\lib\site-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\aryan\anaconda3\lib\site-packages (from wordcloud) (2.3.4)
# Requirement already satisfied: pillow in c:\users\aryan\anaconda3\lib\site-packages (from wordcloud) (11.1.0)
# Requirement already satisfied: matplotlib in c:\users\aryan\anaconda3\lib\site-packages (from wordcloud) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\aryan\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\aryan\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\aryan\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\aryan\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\aryan\anaconda3\lib\site-packages (from matplotlib->wordcloud) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\aryan\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\aryan\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\aryan\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)

# %%
from wordcloud import WordCloud
wc = WordCloud(width =800,height = 800,min_font_size = 10, background_color = 'white')

# %%
# for spam messgaes
spam_wc = wc.generate(df[df['target']== 1]['transformed_text'].str.cat(sep=" "))

# %%
plt.imshow(spam_wc)
plt.axis('off') 
plt.show()

# %%
#for ham messages
ham_wc = wc.generate(df[df['target']== 0]['transformed_text'].str.cat(sep=" "))

# %%
plt.imshow(ham_wc)
plt.axis('off') 
plt.show()

# %%
spam_corpus = []
for msg in df[df['target'] == 1]['transformed_text'].tolist():
    for word in msg.split():
        spam_corpus.append(word)

# %%
len(spam_corpus)
# Out:
# 9939

# %%
from collections import Counter
sns.barplot(x=pd.DataFrame(Counter(spam_corpus).most_common(30))[0],y=pd.DataFrame(Counter(spam_corpus).most_common(30))[1])
plt.xticks(rotation='vertical')
plt.show()

# %%
ham_corpus = []
for msg in df[df['target'] == 0]['transformed_text'].tolist():
    for word in msg.split():
        ham_corpus.append(word)

# %%
len(ham_corpus)
# Out:
# 35404

# %%
from collections import Counter
sns.barplot(x=pd.DataFrame(Counter(ham_corpus).most_common(30))[0],y=pd.DataFrame(Counter(ham_corpus).most_common(30))[1])
plt.xticks(rotation='vertical')
plt.show()

# %%
#text vectorization --> using bag of words
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences                                   transformed_text
# 0         24              2  go jurong point crazi avail bugi n great world...
# 1          8              2                              ok lar joke wif u oni
# 2         37              2  free entri 2 wkli comp win fa cup final tkt 21...
# 3         13              1                u dun say earli hor u c alreadi say
# 4         15              1               nah think goe usf live around though

# %% [markdown]
#  # 4. <u> Model Building

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
cv = CountVectorizer()
tfidf = TfidfVectorizer(max_features=3000) #Change the max_features parameter of TfIdf for better accuracy and precision

# %%
X = tfidf.fit_transform(df['transformed_text']).toarray()

# %%
X.shape
# Out:
# (5169, 3000)

# %%
y = df['target'].values
y
# Out:
# array([0, 0, 1, ..., 0, 0, 0], shape=(5169,))

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test =  train_test_split(X,y,test_size = 0.2, random_state= 2)

# %%
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score

# %%
gnb = GaussianNB()
mnb = MultinomialNB()
bnb = BernoulliNB()

# %%
# for gnb
gnb.fit(X_train,y_train)
y_pred1 = gnb.predict(X_test)
print(accuracy_score(y_test,y_pred1))
print(confusion_matrix(y_test,y_pred1))
print(precision_score(y_test,y_pred1))
# Out:
# 0.8694390715667312
# [[788 108]
#  [ 27 111]]
# 0.5068493150684932

# %%
# for mnb
mnb.fit(X_train,y_train)
y_pred2 = mnb.predict(X_test)
print(accuracy_score(y_test,y_pred2))
print(confusion_matrix(y_test,y_pred2))
print(precision_score(y_test,y_pred2))
# Out:
# 0.9709864603481625
# [[896   0]
#  [ 30 108]]
# 1.0

# %%
# for bnb
bnb.fit(X_train,y_train)
y_pred3 = bnb.predict(X_test)
print(accuracy_score(y_test,y_pred3))
print(confusion_matrix(y_test,y_pred3))
print(precision_score(y_test,y_pred3))
# Out:
# 0.9835589941972921
# [[895   1]
#  [ 16 122]]
# 0.991869918699187

# %% [markdown]
# ### --> we are keeping mnp with tlfid becuase it has best accuracy among all and here accuracy is most important

# %%
# training other modelsas well to see who gives the best accuracy

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier

# %%
# creating objects for all above algorithms with some arguments
svc = SVC(kernel = 'sigmoid', gamma = 1.0)
knc = KNeighborsClassifier()
mnb = MultinomialNB()
dtc = DecisionTreeClassifier(max_depth = 5)
lrc = LogisticRegression(solver = 'liblinear', penalty = 'l1')
rfc = RandomForestClassifier(n_estimators = 50, random_state = 2)
abc = AdaBoostClassifier(n_estimators = 50, random_state = 2)
bc = BaggingClassifier(n_estimators = 50, random_state = 2)
etc = ExtraTreesClassifier(n_estimators = 50, random_state = 2)
gbdt = GradientBoostingClassifier(n_estimators = 50, random_state = 2)
xgb = XGBClassifier(n_estimators = 50, random_state = 2)

# %%
 # creating dictionaries containing algo_names in keys and containing objects in values
clfs = {
    'SVC' : svc,
    'KN' : knc,
    'NB' : mnb,
    'DT' : dtc,
    'LR' : lrc,
    'RF' : rfc,
    'AdaBoost' : abc,
    'BgC' : bc,
    'ETC' : etc,
    'GBDT' : gbdt,
    'xgb' : xgb
}

# %%
# it trains the classifier as per training data and return accuracy and precision 
def train_classifier(clf,X_train,y_train,X_test,y_test):
    clf.fit(X_train,y_train)
    y_pred = clf.predict(X_test)
    accuracy = accuracy_score(y_test,y_pred)
    precision = precision_score(y_test,y_pred)

    return accuracy,precision

# %%
# example to check above function
train_classifier(svc,X_train,y_train,X_test,y_test)
# Out:
# (0.9758220502901354, 0.9747899159663865)

# %%
# now training each model and storing their scores respectively to compare which is best among all 
accuracy_scores = []
precision_scores = []

for name,clf in clfs.items():

    current_accuracy,current_precision = train_classifier(clf, X_train,y_train,X_test,y_test)

    print("For ",name)
    print("Accuracy - ",current_accuracy)
    print("Precision - ",current_precision)

    accuracy_scores.append(current_accuracy)
    precision_scores.append(current_precision)
# Out:
# For  SVC
# Accuracy -  0.9758220502901354
# Precision -  0.9747899159663865
# For  KN
# Accuracy -  0.9052224371373307
# Precision -  1.0
# For  NB
# Accuracy -  0.9709864603481625
# Precision -  1.0
# For  DT
# Accuracy -  0.9294003868471954
# Precision -  0.8282828282828283
# For  LR
# Accuracy -  0.9584139264990329
# Precision -  0.9702970297029703
# For  RF
# Accuracy -  0.9758220502901354
# Precision -  0.9829059829059829
# For  AdaBoost
# Accuracy -  0.9245647969052224
# Precision -  0.8488372093023255
# For  BgC
# Accuracy -  0.9584139264990329
# Precision -  0.8682170542635659
# For  ETC
# Accuracy -  0.9748549323017408
# Precision -  0.9745762711864406
# For  GBDT
# Accuracy -  0.9468085106382979
# Precision -  0.9191919191919192
# For  xgb
# Accuracy -  0.9671179883945842
# Precision -  0.9482758620689655

# %%
performance_df = pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy':accuracy_scores,'Precision':precision_scores}).sort_values('Precision',ascending=False)

# %%
performance_df
# Out:
#    Algorithm  Accuracy  Precision
# 1         KN  0.905222   1.000000
# 2         NB  0.970986   1.000000
# 5         RF  0.975822   0.982906
# 0        SVC  0.975822   0.974790
# 8        ETC  0.974855   0.974576
# 4         LR  0.958414   0.970297
# 10       xgb  0.967118   0.948276
# 9       GBDT  0.946809   0.919192
# 7        BgC  0.958414   0.868217
# 6   AdaBoost  0.924565   0.848837
# 3         DT  0.929400   0.828283

# %%
performance_df = pd.melt(performance_df, id_vars = "Algorithm")

# %%
performance_df
# Out:
#    Algorithm   variable     value
# 0         KN   Accuracy  0.905222
# 1         NB   Accuracy  0.970986
# 2         RF   Accuracy  0.975822
# 3        SVC   Accuracy  0.975822
# 4        ETC   Accuracy  0.974855
# 5         LR   Accuracy  0.958414
# 6        xgb   Accuracy  0.967118
# 7       GBDT   Accuracy  0.946809
# 8        BgC   Accuracy  0.958414
# 9   AdaBoost   Accuracy  0.924565
# 10        DT   Accuracy  0.929400
# 11        KN  Precision  1.000000
# 12        NB  Precision  1.000000
# 13        RF  Precision  0.982906
# 14       SVC  Precision  0.974790
# 15       ETC  Precision  0.974576
# 16        LR  Precision  0.970297
# 17       xgb  Precision  0.948276
# 18      GBDT  Precision  0.919192
# 19       BgC  Precision  0.868217
# 20  AdaBoost  Precision  0.848837
# 21        DT  Precision  0.828283

# %%
# ploting graph for better visualization that which model will be best

sns.catplot(x = 'Algorithm', y = 'value',hue = 'variable', data = performance_df, kind = 'bar',height = 5)
plt.ylim(0.5,1.0)
plt.xticks(rotation = 'vertical')
plt.show()

# %% [markdown]
# ## --> Now, its clear that among all different models multinomial naive bayes performs best, as its precision is 1 and accuracy is also nearest to best one.

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Predict using your trained NB model
y_pred = mnb.predict(X_test)

# Confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Ham", "Spam"])
disp.plot(cmap="Blues")
plt.title("Confusion Matrix - Multinomial Naive Bayes")
plt.show()

# %%
import pickle
pickle.dump(tfidf, open('vectorizer.pkl','wb'))
pickle.dump(mnb,open('model.pkl','wb'))

# %%
print(tfidf.vocabulary_)
# Out:
# {'go': np.int64(1146), 'point': np.int64(1984), 'crazi': np.int64(717), 'avail': np.int64(367), 'bugi': np.int64(509), 'great': np.int64(1175), 'world': np.int64(2936), 'la': np.int64(1465), 'buffet': np.int64(508), 'cine': np.int64(625), 'got': np.int64(1164), 'wat': np.int64(2854), 'ok': np.int64(1853), 'lar': np.int64(1477), 'joke': np.int64(1415), 'wif': np.int64(2899), 'oni': np.int64(1862), 'free': np.int64(1085), 'entri': np.int64(934), 'wkli': np.int64(2920), 'comp': np.int64(668), 'win': np.int64(2904), 'fa': np.int64(988), 'cup': np.int64(733), 'final': np.int64(1040), 'tkt': np.int64(2655), '21st': np.int64(78), 'may': np.int64(1640), 'text': np.int64(2602), 'receiv': np.int64(2122), 'question': np.int64(2078), 'std': np.int64(2466), 'txt': np.int64(2726), 'rate': np.int64(2099), 'appli': np.int64(317), 'dun': np.int64(876), 'say': np.int64(2242), 'earli': np.int64(881), 'hor': np.int64(1274), 'alreadi': np.int64(271), 'nah': np.int64(1761), 'think': np.int64(2621), 'goe': np.int64(1149), 'usf': np.int64(2787), 'live': np.int64(1535), 'around': np.int64(337), 'though': np.int64(2628), 'freemsg': np.int64(1088), 'hey': np.int64(1244), 'darl': np.int64(751), 'week': np.int64(2870), 'word': np.int64(2933), 'back': np.int64(382), 'like': np.int64(1521), 'fun': np.int64(1103), 'still': np.int64(2473), 'tb': np.int64(2576), 'xxx': np.int64(2962), 'chg': np.int64(607), 'send': np.int64(2278), 'rcv': np.int64(2102), 'even': np.int64(953), 'brother': np.int64(494), 'speak': np.int64(2427), 'treat': np.int64(2700), 'aid': np.int64(247), 'per': np.int64(1933), 'request': np.int64(2159), 'oru': np.int64(1882), 'set': np.int64(2290), 'callertun': np.int64(538), 'caller': np.int64(537), 'press': np.int64(2028), 'copi': np.int64(699), 'friend': np.int64(1095), 'winner': np.int64(2908), 'valu': np.int64(2795), 'network': np.int64(1792), 'custom': np.int64(737), 'select': np.int64(2271), 'prize': np.int64(2039), 'reward': np.int64(2177), 'claim': np.int64(629), 'call': np.int64(533), 'code': np.int64(652), 'valid': np.int64(2793), '12': np.int64(53), 'hour': np.int64(1282), 'mobil': np.int64(1705), '11': np.int64(51), 'month': np.int64(1723), 'entitl': np.int64(933), 'updat': np.int64(2769), 'latest': np.int64(1482), 'colour': np.int64(660), 'camera': np.int64(544), 'co': np.int64(647), 'gon': np.int64(1152), 'na': np.int64(1759), 'home': np.int64(1268), 'soon': np.int64(2412), 'want': np.int64(2848), 'talk': np.int64(2564), 'stuff': np.int64(2496), 'anymor': np.int64(302), 'tonight': np.int64(2673), 'cri': np.int64(724), 'enough': np.int64(929), 'today': np.int64(2662), 'six': np.int64(2357), 'chanc': np.int64(587), 'cash': np.int64(566), '100': np.int64(45), 'pound': np.int64(2009), 'cost': np.int64(702), 'repli': np.int64(2156), 'hl': np.int64(1254), 'info': np.int64(1348), 'urgent': np.int64(2777), 'membership': np.int64(1661), 'pobox': np.int64(1978), 'search': np.int64(2257), 'right': np.int64(2182), 'thank': np.int64(2608), 'promis': np.int64(2051), 'wont': np.int64(2931), 'take': np.int64(2560), 'help': np.int64(1238), 'wonder': np.int64(2930), 'bless': np.int64(446), 'time': np.int64(2647), 'date': np.int64(755), 'sunday': np.int64(2519), 'use': np.int64(2785), 'credit': np.int64(721), 'click': np.int64(637), 'wap': np.int64(2849), 'link': np.int64(1526), 'next': np.int64(1798), 'messag': np.int64(1670), 'http': np.int64(1290), 'oh': np.int64(1849), 'watch': np.int64(2855), 'eh': np.int64(903), 'rememb': np.int64(2145), 'spell': np.int64(2434), 'name': np.int64(1765), 'ye': np.int64(2971), 'naughti': np.int64(1776), 'make': np.int64(1615), 'wet': np.int64(2885), 'fine': np.int64(1043), 'thatåõ': np.int64(2612), 'way': np.int64(2858), 'feel': np.int64(1024), 'england': np.int64(926), 'dont': np.int64(845), 'miss': np.int64(1691), 'news': np.int64(1797), 'ur': np.int64(2775), 'nation': np.int64(1774), 'team': np.int64(2581), '87077': np.int64(172), 'eg': np.int64(901), 'tri': np.int64(2702), 'wale': np.int64(2841), 'scotland' ...
